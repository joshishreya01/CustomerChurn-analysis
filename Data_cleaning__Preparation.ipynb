# %% [markdown]
# <a href="https://colab.research.google.com/github/joshishreya01/CustomerChurn-analysis/blob/main/Data_cleaning__Preparation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Installing libraries
import pandas as pd
import ast

# %%
trxn= pd.read_csv('Retail_Transactions_Dataset.csv.zip')

# %%
trxn
# Out:
#        customer_id trans_date  tran_amount
# 0           CS5295  11-Feb-13           35
# 1           CS4768  15-Mar-15           39
# 2           CS2122  26-Feb-13           52
# 3           CS1217  16-Nov-11           99
# 4           CS1850  20-Nov-13           78
# ...            ...        ...          ...
# 124995      CS8433  26-Jun-11           64
# 124996      CS7232  19-Aug-14           38
# 124997      CS8731  28-Nov-14           42
# 124998      CS8133  14-Dec-13           13
# 124999      CS7996  13-Dec-14           36
#
# [125000 rows x 3 columns]

# %%
df = pd.read_csv('Retail_Transactions_Dataset.csv.zip')

# %%
# Ensure dataframe is properly loaded
if df is None or df.empty:
    raise ValueError("DataFrame is not loaded properly. Check the file path and format.")

# %%
# Convert 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# %%
# features

df.dtypes
df.shape
df.tail()
# Out:
#         Transaction_ID                Date      Customer_Name  \
# 999995      1000999995 2023-03-27 06:12:10      Lisa Gonzalez
# 999996      1000999996 2022-05-19 05:13:58       Emily Graham
# 999997      1000999997 2021-09-03 13:59:39   Cynthia Anderson
# 999998      1000999998 2023-10-17 05:50:40  Michael Rodriguez
# 999999      1000999999 2020-06-15 11:58:49     Jennifer Davis
#
#                                                   Product  Total_Items  \
# 999995  ['Pickles', 'Carrots', 'Peanut Butter', 'Spong...            1
# 999996                                         ['Cereal']            8
# 999997                                     ['Trash Bags']            3
# 999998             ['Diapers', 'Coffee', 'Coffee', 'Mop']            3
# 999999                       ['Trash Cans', 'Mop', 'Jam']            8
#
#         Total_Cost Payment_Method           City         Store_Type  \
# 999995       22.07     Debit Card    Los Angeles        Supermarket
# ...

# %%
df.describe()
# Out:
#        Transaction_ID                           Date     Total_Items  \
# count    1.000000e+06                        1000000  1000000.000000
# mean     1.000500e+09  2022-03-10 21:46:28.440430080        5.495941
# min      1.000000e+09            2020-01-01 00:03:54        1.000000
# 25%      1.000250e+09  2021-02-03 23:15:59.249999872        3.000000
# 50%      1.000500e+09     2022-03-10 19:23:17.500000        5.000000
# 75%      1.000750e+09            2023-04-14 23:06:37        8.000000
# max      1.001000e+09            2024-05-18 19:31:03       10.000000
# std      2.886753e+05                            NaN        2.871654
#
#            Total_Cost
# count  1000000.000000
# mean        52.455220
# min          5.000000
# 25%         28.710000
# 50%         52.420000
# 75%         76.190000
# max        100.000000
# std         27.416989

# %%
# MISSING VALUES

df.isnull().sum()
# Out:
# Transaction_ID            0
# Date                      0
# Customer_Name             0
# Product                   0
# Total_Items               0
# Total_Cost                0
# Payment_Method            0
# City                      0
# Store_Type                0
# Discount_Applied          0
# Customer_Category         0
# Season                    0
# Promotion            333943
# dtype: int64

# %%
df=df.dropna()

# %%
df
# Out:
#         Transaction_ID                Date      Customer_Name  \
# 1           1000000001 2023-03-01 13:01:21   Michelle Carlson
# 4           1000000004 2020-12-10 00:59:59     Susan Mitchell
# 5           1000000005 2021-10-07 12:37:26     Joshua Frazier
# 6           1000000006 2023-01-08 10:40:03   Victoria Garrett
# 7           1000000007 2020-09-03 12:39:59      Sydney Waller
# ...                ...                 ...                ...
# 999993      1000999993 2022-01-02 19:40:32     Donna Hamilton
# 999994      1000999994 2021-03-13 14:12:17     James Villegas
# 999996      1000999996 2022-05-19 05:13:58       Emily Graham
# 999998      1000999998 2023-10-17 05:50:40  Michael Rodriguez
# 999999      1000999999 2020-06-15 11:58:49     Jennifer Davis
#
#                                                   Product  Total_Items  \
# 1       ['Ice Cream', 'Milk', 'Olive Oil', 'Bread', 'P...            2
# 4                                           ['Dish Soap']           10
# ...

# %%
# Convert 'Product' column from string representation of a list to an actual list
df['Product'] = df['Product'].apply(ast.literal_eval)

# %%
df
# Out:
#         Transaction_ID                Date      Customer_Name  \
# 1           1000000001 2023-03-01 13:01:21   Michelle Carlson
# 4           1000000004 2020-12-10 00:59:59     Susan Mitchell
# 5           1000000005 2021-10-07 12:37:26     Joshua Frazier
# 6           1000000006 2023-01-08 10:40:03   Victoria Garrett
# 7           1000000007 2020-09-03 12:39:59      Sydney Waller
# ...                ...                 ...                ...
# 999990      1000999990 2020-03-18 19:54:23      Krista Miller
# 999993      1000999993 2022-01-02 19:40:32     Donna Hamilton
# 999996      1000999996 2022-05-19 05:13:58       Emily Graham
# 999998      1000999998 2023-10-17 05:50:40  Michael Rodriguez
# 999999      1000999999 2020-06-15 11:58:49     Jennifer Davis
#
#                                                   Product  Total_Items  \
# 1           [Ice Cream, Milk, Olive Oil, Bread, Potatoes]            2
# 4                                             [Dish Soap]           10
# ...

# %%
# Remove duplicate Transaction_IDs
df = df.drop_duplicates(subset=['Transaction_ID'])

# %%
df.dtypes
# Out:
# customer_id            object
# trans_date     datetime64[ns]
# tran_amount             int64
# response                int64
# dtype: object

# %%
# Standardize categorical columns by stripping extra spaces
categorical_columns = ['Payment_Method', 'Store_Type', 'Customer_Category', 'Season', 'Promotion']
for col in categorical_columns:
    df[col] = df[col].str.strip()

# %%
# Check for outliers in numerical columns
outlier_thresholds = {
    'Total_Items': df['Total_Items'].quantile(0.99),
    'Total_Cost': df['Total_Cost'].quantile(0.99)
}
df = df[(df['Total_Items'] <= outlier_thresholds['Total_Items']) & (df['Total_Cost'] <= outlier_thresholds['Total_Cost'])]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x=df['Total_Items'])
plt.show()

# %%
# Create new columns
if 'Date' in df.columns:
    df['Month'] = df['Date'].dt.month
    df['Year'] = df['Date'].dt.year

# %%
df
# Out:
#        customer_id trans_date  tran_amount  response  month
# 0           CS5295 2013-02-11           35         1      2
# 1           CS4768 2015-03-15           39         1      3
# 2           CS2122 2013-02-26           52         0      2
# 3           CS1217 2011-11-16           99         0     11
# 4           CS1850 2013-11-20           78         0     11
# ...            ...        ...          ...       ...    ...
# 124995      CS8433 2011-06-26           64         0      6
# 124996      CS7232 2014-08-19           38         0      8
# 124997      CS8731 2014-11-28           42         0     11
# 124998      CS8133 2013-12-14           13         0     12
# 124999      CS7996 2014-12-13           36         0     12
#
# [124969 rows x 5 columns]

# %%
# Identify the top 3 months with highest transaction amounts
monthly_Sales = df.groupby('Month')['Total_Cost'].sum()
monthly_Sales = monthly_Sales.sort_values(ascending=False).reset_index().head(3)
print("Top 3 months with highest transaction amounts:")
print(monthly_Sales)
# Out:
# Top 3 months with highest transaction amounts:
#    Month  Total_Cost
# 0      3  3326540.36
# 1      1  3310606.87
# 2      4  3199562.64

# %%
print(df.columns)
# Out:
# Index(['Transaction_ID', 'Date', 'Customer_Name', 'Product', 'Total_Items',
#        'Total_Cost', 'Payment_Method', 'City', 'Store_Type',
#        'Discount_Applied', 'Customer_Category', 'Season', 'Promotion', 'Month',
#        'Year'],
#       dtype='object')

# %%
# Identify top 5 customers with highest number of discount
customer_counts = df['Customer_Name'].value_counts().reset_index()
customer_counts.columns = ['Customer_Name', 'Discount_Applied']
top_5_customers = customer_counts.sort_values(by='Discount_Applied', ascending=False).head(5)
print("Top 5 customers with highest number of orders:")
print(top_5_customers)
# Out:
# Top 5 customers with highest number of orders:
#       Customer_Name  Discount_Applied
# 0     Michael Smith               293
# 1   Michael Johnson               229
# 2       James Smith               215
# 3  Michael Williams               206
# 4        John Smith               194

# %%
# Identify top 5 customers with highest number of orders
customer_counts = df['Customer_Name'].value_counts().reset_index()
customer_counts.columns = ['Customer_Name', 'Order_Count']
top_5_customers = customer_counts.sort_values(by='Order_Count', ascending=False).head(5)

print("Top 5 customers with highest number of orders:")
print(top_5_customers)
# Out:
# Top 5 customers with highest number of orders:
#       Customer_Name  Order_Count
# 0     Michael Smith          293
# 1   Michael Johnson          229
# 2       James Smith          215
# 3  Michael Williams          206
# 4        John Smith          194

# %%
#plotting the top 5 customers

import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(x='Customer_Name', y='Order_Count', data=top_5_customers)
plt.xticks(rotation=45)
plt.xlabel("Customer Name")
plt.ylabel("Number of Orders")
plt.title("Top 5 Customers with Highest Orders")
plt.show()

# %%
# Customers having highest value of orders

customer_sales= df.groupby('customer_id')['tran_amount'].sum().reset_index()
customer_sales

# sort

top_5_sal= customer_sales.sort_values(by='tran_amount', ascending=False).head(5)
top_5_sal
# Out:
#      customer_id  tran_amount
# 3312      CS4424         2933
# 3208      CS4320         2647
# 4640      CS5752         2612
# 3548      CS4660         2527
# 2687      CS3799         2513

# %%
sns.barplot(x='customer_id',y='tran_amount',data=top_5_sal)
# Out:
# <AxesSubplot:xlabel='customer_id', ylabel='tran_amount'>

# %% [markdown]
# ## Advanced Analytics

# %% [markdown]
# ### Time Series Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Create a new column 'month_year' for grouping sales
df['month_year'] = df['Date'].dt.to_period('M')

# Group by 'month_year' and sum the 'Total_Cost' to get monthly sales
monthly_sales = df.groupby('month_year')['Total_Cost'].sum()

# Convert PeriodIndex to DateTimeIndex for plotting
monthly_sales.index = monthly_sales.index.to_timestamp()

# Plot Monthly Sales
plt.figure(figsize=(12,6))
plt.plot(monthly_sales.index, monthly_sales.values, marker='o', linestyle='-')

# Formatting x-axis
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))

# Labels and title
plt.xlabel('Month-Year')
plt.ylabel('Total Sales')
plt.title('Monthly Sales Over Time')
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.6)  # Adding grid for better readability
plt.tight_layout()

plt.show()

# %% [markdown]
# ### Cohort Segmentation

# %%
# Recency: The most recent transaction date per customer
recency = df.groupby('Customer_Name')['Date'].max()

# Frequency: Count of transactions per customer
frequency = df.groupby('Customer_Name')['Date'].count()

# Monetary: Total amount spent per customer
monetary = df.groupby('Customer_Name')['Total_Cost'].sum()

# Combine all three metrics into an RFM DataFrame
rfm = pd.DataFrame({'Recency': recency, 'Frequency': frequency, 'Monetary': monetary})

# Convert Recency to days since last purchase (assuming today is the latest date in the dataset)
latest_date = df['Date'].max()
rfm['Recency'] = (latest_date - rfm['Recency']).dt.days

# Display the RFM DataFrame
print("RFM Analysis:")
print(rfm.head())

# Save the RFM data to a CSV file
rfm.to_csv("Retail_RFM_Analysis.csv", index=True)
print("RFM analysis saved as 'Retail_RFM_Analysis.csv'.")
# Out:
# RFM Analysis:
#                Recency  Frequency  Monetary
# Customer_Name
# Aaron Acevedo      936          2     89.80
# Aaron Acosta       836          3    215.32
# Aaron Adams         33          8    456.64
# Aaron Adkins      1267          1     30.30
# Aaron Aguilar       56          3    116.03
# RFM analysis saved as 'Retail_RFM_Analysis.csv'.

# %%
# RFM Analysis
latest_date = df['Date'].max()

rfm = df.groupby('Customer_Name').agg({
    'Date': lambda x: (latest_date - x.max()).days,  # Recency
    'Transaction_ID': 'count',  # Frequency
    'Total_Cost': 'sum'  # Monetary
}).reset_index()

rfm.columns = ['Customer_Name', 'Recency', 'Frequency', 'Monetary']

# Customer Segmentation
def segment_customer(row):
    if row['Recency'] <= 30 and row['Frequency'] >= 15 and row['Monetary'] > 1000:
        return 'P0'
    elif (30 < row['Recency'] <= 90) and (10 < row['Frequency'] <= 15) and (500 < row['Monetary'] <= 1000):
        return 'P1'
    else:
        return 'P2'

rfm['Segment'] = rfm.apply(segment_customer, axis=1)

# %%
rfm
# Out:
#         Customer_Name  Recency  Frequency  Monetary Segment
# 0       Aaron Acevedo      936          2     89.80      P2
# 1        Aaron Acosta      836          3    215.32      P2
# 2         Aaron Adams       33          8    456.64      P2
# 3        Aaron Adkins     1267          1     30.30      P2
# 4       Aaron Aguilar       56          3    116.03      P2
# ...               ...      ...        ...       ...     ...
# 260804     Zoe Wilson      263          2    126.80      P2
# 260805       Zoe Wong      781          1      5.33      P2
# 260806       Zoe Wood     1114          1     21.82      P2
# 260807   Zoe Woodward      703          1     62.07      P2
# 260808       Zoe York      111          1     78.12      P2
#
# [260809 rows x 5 columns]

# %%
set(rfm['Segment'])
# Out:
# {'P0', 'P1', 'P2'}

# %% [markdown]
# ### Churn Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define churn threshold (e.g., 180 days without a transaction)
churn_threshold = 180
latest_date = df['Date'].max()

# Identify churned customers
df['Last_Purchase'] = df.groupby('Customer_Name')['Date'].transform('max')
df['Churn_Status'] = df['Last_Purchase'].apply(lambda x: 'Churned' if (latest_date - x).days > churn_threshold else 'Active')

# Count churned and active customers
churn_counts = df['Churn_Status'].value_counts()

# Plot
plt.figure(figsize=(6, 4))
churn_counts.plot(kind='bar', color=['red', 'green'])
plt.xlabel('Customer Status')
plt.ylabel('Count')
plt.title('Churned vs Active Customers')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### Analyzing top customers

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Ensure 'Date' is in datetime format
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# Create a 'month_year' column
df['month_year'] = df['Date'].dt.to_period('M')

# Calculate monetary value per customer (total cost spent)
monetary = df.groupby('Customer_Name')['Total_Cost'].sum()

# Get top 5 customers based on total spend
top_5_customers = monetary.sort_values(ascending=False).head(5).index

# Filter transactions of top 5 customers
top_customers_df = df[df['Customer_Name'].isin(top_5_customers)]

# Aggregate their monthly sales
top_customers_sales = top_customers_df.groupby(['month_year', 'Customer_Name'])['Total_Cost'].sum().unstack(level=1)

# Convert PeriodIndex to DateTimeIndex for plotting
top_customers_sales.index = top_customers_sales.index.to_timestamp()

# Plot
plt.figure(figsize=(12, 6))
top_customers_sales.plot(kind='line', marker='o', ax=plt.gca())

plt.xlabel('Month-Year')
plt.ylabel('Sales (Total Cost)')
plt.title('Monthly Sales of Top 5 Customers')
plt.legend(title='Customer Name')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
